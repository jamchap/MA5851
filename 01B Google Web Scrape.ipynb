# %% [markdown]
# # Web Scraping Google Search Results

# %%
import pandas as pd
import numpy as np
import time
import random
import regex as re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# Custom functions
from my_functions import *

# %% [markdown]
# ## Web Scrape Mojo Website
# Form initial list of movies based off the Box Office Mojo website

# %%
# Import Box Office Mojo Movie list
df_movies = pd.read_csv('bk_mojo.csv', dtype=object)
df_movies.head()
# Out:
#                                         Title Worldwide Lifetime Gross  \
# 0                                      Avatar           $2,847,246,203
# 1                           Avengers: Endgame           $2,797,501,328
# 2                                     Titanic           $2,201,647,264
# 3  Star Wars: Episode VII - The Force Awakens           $2,069,521,700
# 4                      Avengers: Infinity War           $2,048,359,754
#
#   Domestic Lifetime Gross Domestic % Foreign Lifetime Gross Foreign %  Year
# 0            $760,507,625      26.7%         $2,086,738,578     73.3%  2009
# 1            $858,373,000      30.7%         $1,939,128,328     69.3%  2019
# 2            $659,363,944        30%         $1,542,283,320       70%  1997
# 3            $936,662,225      45.3%         $1,132,859,475     54.7%  2015
# 4            $678,815,482      33.1%         $1,369,544,272     66.9%  2018

# %% [markdown]
# ## Web Scrape Google Search Results

# %% [markdown]
# ### First search of movies

# %%
movies = df_movies.loc[:, ['Title', 'Year']]
print('Number of movies: ', len(df_movies))
# Out:
# Number of movies:  1000

# %%
# %%time

lst_scores = []
lst_like = []
lst_g_rev = []
lst_dist = []
lst_combined= []
loop_rand = random.randrange(10, 40)
loop_reset = 1
loop_counter = 1

driver = webdriver.Chrome('./chromedriver')
driver.get("https://www.google.com/")

# df_movies = missing_movies

for index, movie in df_movies.iterrows():

    # Print stage in loop every 25 movies
    if loop_counter % 25 == 0:
        print('Loops completed: ', loop_counter)
    loop_counter += 1

    search = driver.find_element_by_name('q')
    search.send_keys(movie['Title']+ ' film '+  movie['Year'])
    search.send_keys(Keys.RETURN)

    # Movie review scores
    try:
        lst = google_scrape('//*[@id="kp-wp-tab-overview"]/div[1]/div/div/div[2]/div/div[1]/div[1]', driver)
        lst1_dict = [{'Title': movie['Title']
                    , 'Year': movie['Year']
                    , lst[1] : lst[0]
                    , lst[3] : lst[2]
                    , lst[5] : lst[4]}]
        lst_scores.append(lst1_dict)
    except:
        pass

    # Did Google users like the movie?
    try:
        lst1_like = google_scrape('//*[@id="kp-wp-tab-overview"]/div[1]/div/div/div[2]/div/div[2]/div/div[1]/div', driver)
        lst_like.append(lst1_like)
    except:
        pass

    # Google User Reviews Score
    for i in [2, 3, 4,5,6]:
        try: 
            path = '//*[@id="kp-wp-tab-overview"]/div[' + str(i) + ']/div/div/div/div/div/div/div/div[2]/div[2]'
            lst1_g_rev = google_scrape(path, driver)
            lst_g_rev.append(lst1_g_rev)
            break
        except:
            pass    

    # Film description (from Google)
    try:
        lst1_dist = google_scrape('//*[@id="kp-wp-tab-overview"]/div[1]/div/div/div[2]/div/div[3]/div/div/div', driver)
        lst_dist.append(lst1_dist)
    except:
        pass    

    # Combine everything except the agggregated movie reviews
    lst_combined.append([movie['Title']
                        , movie['Year']
                        , lst1_like
                        , lst1_g_rev
                        , lst1_dist])
                        #, lst1_dict])

    # Empty lists
    lst1_like = []
    lst1_g_rev = []
    lst1_dist = []
    lst1_dict = []

    # Clear search bar
    driver.find_element_by_name('q').clear()

    # Wait random amount of time
    time.sleep(np.random.random() * 5)

    # Close and re-open driver at random interval to try to avoid Google's block
    loop_reset += 1
    if loop_reset >= loop_rand:
        loop_rand = random.randrange(20, 50)
        loop_reset = 1

        driver.close()
        driver = webdriver.Chrome('./chromedriver')
        driver.get("https://www.google.com/")

driver.close()
# Out:
# <timed exec>:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# <timed exec>:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# <timed exec>:77: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# Loops completed:  25
# <timed exec>:89: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# Loops completed:  50
# Loops completed:  75
# Loops completed:  100
# Loops completed:  125
# Loops completed:  150
# Loops completed:  175
# Loops completed:  200
# Loops completed:  225
# Loops completed:  250
# Loops completed:  275
# Loops completed:  300
# Loops completed:  325
# Loops completed:  350
# Loops completed:  375
# Loops completed:  400
# Loops completed:  425
# Loops completed:  450
# Loops completed:  475
# Loops completed:  500
# Loops completed:  525
# Loops completed:  550
# Loops completed:  575
# Loops completed:  600
# Loops completed:  625
# Loops completed:  650
# Loops completed:  675
# Loops completed:  700
# Loops completed:  725
# Loops completed:  750
# Loops completed:  775
# Loops completed:  800
# Loops completed:  825
# Loops completed:  850
# Loops completed:  875
# Loops completed:  900
# Loops completed:  925
# Loops completed:  950
# Loops completed:  975
# Loops completed:  1000
# Wall time: 1h 17min 33s

# %%
col_names = ['Title'
             , 'Year'
             , 'Google_Users'
             , 'Google user ratings'
             , 'movie description']

df_google = pd.DataFrame(lst_combined, columns = col_names)

# Backup Movie list
df_google.to_csv('bk_google_1_raw.csv', index = False)

df_google.tail()
# Out:
#                                  Title  Year  \
# 995                   Operation Mekong  2016
# 996  Anchorman 2: The Legend Continues  2013
# 997                              Creed  2015
# 998                         Gemini Man  2019
# 999              The Girl on the Train  2016
#
#                             Google_Users  Google user ratings  \
# 995  [85% liked this film, Google users]                   []
# 996  [83% liked this film, Google users]    [4.0, 93 ratings]
# 997  [91% liked this film, Google users]   [4.6, 619 ratings]
# 998  [75% liked this film, Google users]  [3.8, 2583 ratings]
# 999  [77% liked this film, Google users]   [3.6, 872 ratings]
#
#                                      movie description
# 995  [Description, The Chinese government launches ...
# 996  [Description, A celebrated news anchor from Sa...
# 997  [Description, Adonis Johnson, the son of heavy...
# 998  [Description, Henry is an ageing assassin who ...
# 999  [Description, Rachel, a divorcee, idealises Sc...

# %% [markdown]
# ### Missing Movies to search for again

# %%
missing_movies = []

for index, movie in df_google.iterrows():
    if (movie['Google_Users'] == [] 
        or movie['Google user ratings'] == []
        or movie['movie description'] == []):
        missing_movies.append(movie) 
        
missing_movies = pd.DataFrame(missing_movies)# .loc[:, ['Title', 'Year']]
missing_movies['Year'] = missing_movies['Year'].astype('str') 
print(len(missing_movies), 'movies to run search for again')
missing_movies.head()
# Out:
# 61 movies to run search for again
#                                      Title  Year  \
# 65          Ice Age: Dawn of the Dinosaurs  2009
# 83                            Wonder Woman  2017
# 106                         No Time to Die  2021
# 107  The Hunger Games: Mockingjay - Part 1  2014
# 115                                     Up  2009
#
#                             Google_Users Google user ratings  \
# 65   [89% liked this film, Google users]                  []
# 83   [84% liked this film, Google users]                  []
# 106  [89% liked this film, Google users]                  []
# 107  [86% liked this film, Google users]                  []
# 115  [89% liked this film, Google users]                  []
#
#                                      movie description
# 65   [Description, Manny and Ellie are expecting th...
# 83   [Description, Princess Diana of an all-female ...
# 106  [Description, James Bond is enjoying a tranqui...
# 107  [Description, After putting a permanent end to...
# 115  [Description, Carl, an old widower, goes off o...

# %%
# %%time

lst_scores2 = []
lst_like2 = []
lst_g_rev2 = []
lst_dist2 = []
lst_combined2 = []

loop_rand = random.randrange(10, 40)
loop_reset = 1
loop_counter = 1

driver = webdriver.Chrome('./chromedriver')
driver.get("https://www.google.com/")

# df_movies = missing_movies

for index, movie in missing_movies.iterrows():

    # Print stage in loop every 25 movies
    if loop_counter % 25 == 0:
        print('Loops completed: ', loop_counter)
    loop_counter += 1

    search = driver.find_element_by_name('q')
    search.send_keys(movie['Title']+ ' film '+  movie['Year'])
    search.send_keys(Keys.RETURN)

    # Movie review scores
    try:
        lst = google_scrape('//*[@id="kp-wp-tab-overview"]/div[1]/div/div/div[2]/div/div[1]/div[1]', driver)
        lst1_dict = [{'Title': movie['Title']
                    , 'Year': movie['Year']
                    , lst[1] : lst[0]
                    , lst[3] : lst[2]
                    , lst[5] : lst[4]}]
        lst_scores2.append(lst1_dict)
    except:
        pass

    # Did Google users like the movie?
    try:
        lst1_like = google_scrape('//*[@id="kp-wp-tab-overview"]/div[1]/div/div/div[2]/div/div[2]/div/div[1]/div', driver)
        lst_like2.append(lst1_like)
    except:
        pass

    # Google User Reviews Score
    for i in [2, 3, 4,5,6]:
        try: 
            path = '//*[@id="kp-wp-tab-overview"]/div[' + str(i) + ']/div/div/div/div/div/div/div/div[2]/div[2]'
            lst1_g_rev = google_scrape(path, driver)
            lst_g_rev2.append(lst1_g_rev)
            break
        except:
            pass    

    # Film description (from Google)
    try:
        lst1_dist = google_scrape('//*[@id="kp-wp-tab-overview"]/div[1]/div/div/div[2]/div/div[3]/div/div/div', driver)
        lst_dist2.append(lst1_dist)
    except:
        pass    

    # Combine everything except the agggregated movie reviews
    lst_combined2.append([movie['Title']
                        , movie['Year']
                        , lst1_like
                        , lst1_g_rev
                        , lst1_dist])
                        #, lst1_dict])

    # Empty lists
    lst1_like = []
    lst1_g_rev = []
    lst1_dist = []
    lst1_dict = []

    # Clear search bar
    driver.find_element_by_name('q').clear()

    # Wait random amount of time
    time.sleep(np.random.random() * 10)

    # Close and re-open driver at random interval to try to avoid Google's block
    loop_reset += 1
    if loop_reset >= loop_rand:
        loop_rand = random.randrange(20, 50)
        loop_reset = 1

        driver.close()
        driver = webdriver.Chrome('./chromedriver')
        driver.get("https://www.google.com/")

driver.close()
# Out:
# <timed exec>:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# <timed exec>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# <timed exec>:78: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# Loops completed:  25
# <timed exec>:90: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# Loops completed:  50
# Wall time: 8min 16s

# %%
df_google2 = pd.DataFrame(lst_combined2, columns = col_names)

# Backup Movie list
df_google2.to_csv('bk_google_2_raw.csv', index = False)

df_google2.head()
# Out:
#                                    Title  Year  \
# 0         Ice Age: Dawn of the Dinosaurs  2009
# 1                           Wonder Woman  2017
# 2                         No Time to Die  2021
# 3  The Hunger Games: Mockingjay - Part 1  2014
# 4                                     Up  2009
#
#                           Google_Users   Google user ratings  \
# 0  [89% liked this film, Google users]    [4.6, 319 ratings]
# 1  [84% liked this film, Google users]   [4.1, 3411 ratings]
# 2  [89% liked this film, Google users]  [3.5, 17261 ratings]
# 3  [86% liked this film, Google users]    [4.3, 489 ratings]
# 4  [89% liked this film, Google users]   [4.8, 2506 ratings]
#
#                                    movie description
# 0  [Description, Manny and Ellie are expecting th...
# 1  [Description, Princess Diana of an all-female ...
# 2  [Description, James Bond is enjoying a tranqui...
# 3  [Description, After putting a permanent end to...
# 4  [Description, Carl, an old widower, goes off o...

# %% [markdown]
# ### Clean DataFrames
# #### First run

# %%
# Clean up movies scores
df_scores_clean = movie_scores(lst_scores)
df_scores_clean.head()
# Out:
#                                         Title  Year  imdb_score  \
# 0                                      Avatar  2009        0.78
# 1                           Avengers: Endgame  2019        0.84
# 2                                     Titanic  1997        0.78
# 3  Star Wars: Episode VII - The Force Awakens  2015        0.78
# 4                      Avengers: Infinity War  2018        0.84
#
#    rotten_tom_score  metacritic_score
# 0              0.81              0.83
# 1              0.94               NaN
# 2              0.89              0.75
# 3              0.93               NaN
# 4              0.85               NaN

# %%
# Clean up data
df_google_clean = movies_clean(df_google)
df_google_clean.head()
# Out:
#                                         Title  Year  google_use_like  \
# 0                                      Avatar  2009             0.86
# 1                           Avengers: Endgame  2019             0.94
# 2                                     Titanic  1997             0.94
# 3  Star Wars: Episode VII - The Force Awakens  2015             0.80
# 4                      Avengers: Infinity War  2018             0.92
#
#    google_use_score  google_use_n_rev  \
# 0              0.90            4274.0
# 1              0.94           22212.0
# 2              0.94            8466.0
# 3              0.66            2252.0
# 4              0.94            5519.0
#
#                                    movie_description
# 0  Jake, who is paraplegic, replaces his twin on ...
# 1  After Thanos, an intergalactic warlord, disint...
# 2  Seventeen-year-old Rose hails from an aristocr...
# 3  A new order threatens to destroy the New Repub...
# 4  The Avengers must stop Thanos, an intergalacti...

# %%
# Merge to main dataframe
df_combined = df_google_clean.merge(df_scores_clean
                             , how = 'left'
                             , on = ['Title', 'Year'])
df_combined.head()
# Out:
#                                         Title  Year  google_use_like  \
# 0                                      Avatar  2009             0.86
# 1                           Avengers: Endgame  2019             0.94
# 2                                     Titanic  1997             0.94
# 3  Star Wars: Episode VII - The Force Awakens  2015             0.80
# 4                      Avengers: Infinity War  2018             0.92
#
#    google_use_score  google_use_n_rev  \
# 0              0.90            4274.0
# 1              0.94           22212.0
# 2              0.94            8466.0
# 3              0.66            2252.0
# 4              0.94            5519.0
#
#                                    movie_description  imdb_score  \
# 0  Jake, who is paraplegic, replaces his twin on ...        0.78
# 1  After Thanos, an intergalactic warlord, disint...        0.84
# 2  Seventeen-year-old Rose hails from an aristocr...        0.78
# 3  A new order threatens to destroy the New Repub...        0.78
# 4  The Avengers must stop Thanos, an intergalacti...        0.84
#
#    rotten_tom_score  metacritic_score
# 0              0.81              0.83
# 1              0.94               NaN
# 2              0.89              0.75
# 3              0.93               NaN
# 4              0.85               NaN

# %% [markdown]
# #### Second Pass

# %%
# Movie Scores
df_scores_clean2 = movie_scores(lst_scores2)
df_scores_clean2.head()
# Out:
#                                    Title  Year  imdb_score  rotten_tom_score  \
# 0         Ice Age: Dawn of the Dinosaurs  2009        0.69              0.46
# 1                           Wonder Woman  2017        0.74              0.93
# 2                         No Time to Die  2021        0.74              0.84
# 3  The Hunger Games: Mockingjay - Part 1  2014        0.66              0.69
# 4                                     Up  2009        0.82              0.98
#
#    metacritic_score
# 0               NaN
# 1              0.76
# 2               NaN
# 3               NaN
# 4               NaN

# %%
# Main dataframe
df_google_clean2 = movies_clean(df_google2)
df_google_clean2.head()
# Out:
#                                    Title  Year  google_use_like  \
# 0         Ice Age: Dawn of the Dinosaurs  2009             0.89
# 1                           Wonder Woman  2017             0.84
# 2                         No Time to Die  2021             0.89
# 3  The Hunger Games: Mockingjay - Part 1  2014             0.86
# 4                                     Up  2009             0.89
#
#    google_use_score  google_use_n_rev  \
# 0              0.92             319.0
# 1              0.82            3411.0
# 2              0.70           17261.0
# 3              0.86             489.0
# 4              0.96            2506.0
#
#                                    movie_description
# 0  Manny and Ellie are expecting their first chil...
# 1  Princess Diana of an all-female Amazonian race...
# 2  James Bond is enjoying a tranquil life in Jama...
# 3  After putting a permanent end to the games, Ka...
# 4  Carl, an old widower, goes off on an adventure...

# %%
# Merge to main dataframe
df_combined2 = df_google_clean2.merge(df_scores_clean2
                                 , how = 'left'
                                 , on = ['Title', 'Year'])

df_combined2.head()
# Out:
#                                    Title  Year  google_use_like  \
# 0         Ice Age: Dawn of the Dinosaurs  2009             0.89
# 1                           Wonder Woman  2017             0.84
# 2                         No Time to Die  2021             0.89
# 3  The Hunger Games: Mockingjay - Part 1  2014             0.86
# 4                                     Up  2009             0.89
#
#    google_use_score  google_use_n_rev  \
# 0              0.92             319.0
# 1              0.82            3411.0
# 2              0.70           17261.0
# 3              0.86             489.0
# 4              0.96            2506.0
#
#                                    movie_description  imdb_score  \
# 0  Manny and Ellie are expecting their first chil...        0.69
# 1  Princess Diana of an all-female Amazonian race...        0.74
# 2  James Bond is enjoying a tranquil life in Jama...        0.74
# 3  After putting a permanent end to the games, Ka...        0.66
# 4  Carl, an old widower, goes off on an adventure...        0.82
#
#    rotten_tom_score  metacritic_score
# 0              0.46               NaN
# 1              0.93              0.76
# 2              0.84               NaN
# 3              0.69               NaN
# 4              0.98               NaN

# %% [markdown]
# ### Merge All Data

# %%
# Create ID field for filtering
df_combined['id'] = df_combined['Title'] +'-'+ df_combined['Year']
df_combined2['id'] = df_combined2['Title'] +'-'+ df_combined2['Year']

# Append Original Google Book API search to secondary search
df_combined_final = pd.concat([df_combined.loc[~df_combined['id']
                                              .isin(df_combined2['id'] ), :]
                              ,df_combined2]
                              , axis = 0)

# No duplicates (1000 rows)
print(len(df_combined_final))

#df_combined_final.drop(columns = 'id', inplace = True)
df_combined_final.reset_index(inplace = True, drop = True)

# Output as CSV
df_combined_final.to_csv('bk_google_mojo.csv', index = False)
# Out:
# 1000

# %%
df_combined_final.head()
# Out:
#                                         Title  Year  google_use_like  \
# 0                                      Avatar  2009             0.86
# 1                           Avengers: Endgame  2019             0.94
# 2                                     Titanic  1997             0.94
# 3  Star Wars: Episode VII - The Force Awakens  2015             0.80
# 4                      Avengers: Infinity War  2018             0.92
#
#    google_use_score  google_use_n_rev  \
# 0              0.90            4274.0
# 1              0.94           22212.0
# 2              0.94            8466.0
# 3              0.66            2252.0
# 4              0.94            5519.0
#
#                                    movie_description  imdb_score  \
# 0  Jake, who is paraplegic, replaces his twin on ...        0.78
# 1  After Thanos, an intergalactic warlord, disint...        0.84
# 2  Seventeen-year-old Rose hails from an aristocr...        0.78
# 3  A new order threatens to destroy the New Repub...        0.78
# 4  The Avengers must stop Thanos, an intergalacti...        0.84
#
#    rotten_tom_score  metacritic_score  \
# 0              0.81              0.83
# 1              0.94               NaN
# 2              0.89              0.75
# 3              0.93               NaN
# 4              0.85               NaN
#
#                                                 id
# 0                                      Avatar-2009
# 1                           Avengers: Endgame-2019
# 2                                     Titanic-1997
# 3  Star Wars: Episode VII - The Force Awakens-2015
# 4                      Avengers: Infinity War-2018
